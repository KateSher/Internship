# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Загрузка данных из dataset.csv в DataFrame

# %%
df = pd.read_csv('drive/MyDrive/Colab Notebooks/Internship/lesson_08/dataset.csv', names=['Rank',	
                                                                                          'Name',	
                                                                                          'Platform',	
                                                                                          'Year',	
                                                                                          'Genre',	
                                                                                          'Publisher',	
                                                                                          'NA_Sales',	
                                                                                          'EU_Sales',	
                                                                                          'JP_Sales',	
                                                                                          'Other_Sales',	
                                                                                          'Global_Sales'], 
                                                                                            skiprows=1)
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# ## 2. Вывод заданного количества идущих подряд строк из любой заданной позиции датафрейма

# %%
def part_df(i, n):
    return df.iloc[i:i+n]
part_df(100, 5)
# Out:
#      Rank                                    Name  ... Other_Sales  Global_Sales
# 100   101  The Legend of Zelda: Twilight Princess  ...        0.70          7.31
# 101   102               Call of Duty: Black Ops 3  ...        0.67          7.30
# 102   103                              Just Dance  ...        0.73          7.27
# 103   104                           Battlefield 3  ...        1.10          7.23
# 104   105              Need for Speed Underground  ...        1.02          7.20
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 3. Поиск всех уникальных жанров

# %%
unique_genre = df['Genre'].unique() 
unique_genre
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# ## Разделение загруженного датафрейма по жанровым датафреймам
# ## 4. Упорядочивание строк в каждом жанровом датафрейме по возрастанию в столбце Year
# ## 5. Переиндексация каждого жанрового датафрейма по возрастанию индекса
# ## 6. Сохранение результатов в csv-файлы

# %%
for i in unique_genre:
    df[df['Genre'] == '{}'.format(i)].sort_values('Year', axis=0, ascending=True).reset_index(drop=True)\
    .to_csv('drive/MyDrive/Colab Notebooks/Internship/lesson_08/{}.csv'.format(i))
